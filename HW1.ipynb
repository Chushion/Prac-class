# %% [markdown]
# <a href="https://colab.research.google.com/github/Chushion/Prac-class/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipes

# %%
library(tidyverse)

# %%
cars
# Out:
#    speed dist
# 1   4      2
# 2   4     10
# 3   7      4
# 4   7     22
# 5   8     16
# 6   9     10
# 7  10     18
# 8  10     26
# 9  10     34
# 10 11     17
# 11 11     28
# 12 12     14
# 13 12     20
# 14 12     24
# 15 12     28
# 16 13     26
# 17 13     34
# 18 13     34
# 19 13     46
# 20 14     26
# 21 14     36
# 22 14     60
# 23 14     80
# 24 15     20
# 25 15     26
# 26 15     54
# 27 16     32
# 28 16     40
# 29 17     32
# 30 17     40
# 31 17     50
# 32 18     42
# 33 18     56
# 34 18     76
# 35 18     84
# 36 19     36
# 37 19     46
# 38 19     68
# 39 20     32
# 40 20     48
# 41 20     52
# 42 20     56
# 43 20     64
# 44 22     66
# 45 23     54
# 46 24     70
# 47 24     92
# 48 24     93
# 49 24    120
# 50 25     85

# %%
# Pipe Operator

# summary(cars)
cars %>% summary
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %%
# plot(cars)
cars %>% plot
# Out:
# plot without title

# %% [markdown]
# # Data Transformation - dplyr

# %% [markdown]
# #### nycflight 13
# Dataset on flights deparing New York City in 2013

# %%
install.packages("nycflights13")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nycflights13)

# %%
?flights
# Out:
# Warning message in fetch(key):
# “internal error -3 in R_decompress1”
# ERROR while rich displaying an object: Error in fetch(key): lazy-load database '/usr/local/lib/R/site-library/nycflights13/help/nycflights13.rdb' is corrupt
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
# ...

# %%
flights[1:5,]
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00

# %% [markdown]
# # Fliter rows with filter()

# %% [markdown]
# #### HW1 추가 코드

# %%
flights %>% filter(month == 1 & day == 1 & dest == "IAH") %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   623      627            -4         933      932
# 4 2013 1     1   728      732            -4        1041     1038
# 5 2013 1     1   739      739             0        1104     1038
# 6 2013 1     1   908      908             0        1228     1219
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 11        UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2 20        UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  1        UA       496   N459UA  LGA    IAH  229      1416     6    27
# 4  3        UA       473   N488UA  LGA    IAH  238      1416     7    32
# 5 26        UA      1479   N37408  EWR    IAH  249      1400     7    39
# ...

# %% [markdown]
# #### 수업내용

# %%
flights %>% filter(month == 10 & day == 10) %>% head(3)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 10    10  457      500            -3        637      648
# 2 2013 10    10  515      517            -2        736      757
# 3 2013 10    10  537      545            -8        923      933
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -11       US      1843   N564UW  EWR    CLT   83       529     5     0
# 2 -21       UA       252   N544UA  EWR    IAH  178      1400     5    17
# 3 -10       B6      1403   N608JB  JFK    SJU  203      1598     5    45
#   time_hour
# 1 2013-10-10 05:00:00
# 2 2013-10-10 05:00:00
# 3 2013-10-10 05:00:00

# %%
filter(flights, month == 1, day == 1) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
flights %>% filter(month == 1, day == 1) %>% filter(dest == 'ORD') %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   554      558            -4        740      728
# 2 2013 1     1   558      600            -2        753      745
# 3 2013 1     1   608      600             8        807      735
# 4 2013 1     1   629      630            -1        824      810
# 5 2013 1     1   656      700            -4        854      850
# 6 2013 1     1   709      700             9        852      832
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 12        UA      1696   N39463  EWR    ORD  150      719      5    58
# 2  8        AA       301   N3ALAA  LGA    ORD  138      733      6     0
# 3 32        MQ      3768   N9EAMQ  EWR    ORD  139      719      6     0
# 4 14        AA       303   N3CYAA  LGA    ORD  140      733      6    30
# 5  4        AA       305   N4WNAA  LGA    ORD  143      733      7     0
# ...

# %%
flights %>% filter(month == 1 & day == 1 & dest == 'ORD') %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   554      558            -4        740      728
# 2 2013 1     1   558      600            -2        753      745
# 3 2013 1     1   608      600             8        807      735
# 4 2013 1     1   629      630            -1        824      810
# 5 2013 1     1   656      700            -4        854      850
# 6 2013 1     1   709      700             9        852      832
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 12        UA      1696   N39463  EWR    ORD  150      719      5    58
# 2  8        AA       301   N3ALAA  LGA    ORD  138      733      6     0
# 3 32        MQ      3768   N9EAMQ  EWR    ORD  139      719      6     0
# 4 14        AA       303   N3CYAA  LGA    ORD  140      733      6    30
# 5  4        AA       305   N4WNAA  LGA    ORD  143      733      7     0
# ...

# %% [markdown]
# # Arrange rows with arrange()

# %% [markdown]
# #### HW1 추가코드

# %%
arrange(flights, air_time, distance, hour, minute)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013  4    13   537      527            10        622      628
# 2      2013  1    16  1355     1315            40       1442     1411
# 3      2013  2     3  2153     2129            24       2247     2224
# 4      2013  2    12  2123     2130            -7       2211     2225
# 5      2013  3     8  2026     1935            51       2131     2056
# 6      2013  9     3   722      725            -3        804      822
# 7      2013 12     6   922      851            31       1021      954
# 8      2013  8    18  1129     1138            -9       1206     1234
# 9      2013  9     3  1203     1153            10       1238     1250
# 10     2013  2     5  1303     1315           -12       1342     1411
# 11     2013  3    18  1456     1329            87       1533     1426
# 12     2013  6    12  2338     2129           129         17     2235
# ...

# %%
flights %>% arrange(desc(year, month, day))
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %% [markdown]
# #### 수업내용

# %%
arrange(flights, year, month, day)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %% [markdown]
# # Select columns with select()

# %% [markdown]
# #### HW1 추가코드

# %%
select(flights, dest ,distance) %>% head(10)
# Out:
#    dest distance
# 1  IAH  1400
# 2  IAH  1416
# 3  MIA  1089
# 4  BQN  1576
# 5  ATL   762
# 6  ORD   719
# 7  FLL  1065
# 8  IAD   229
# 9  MCO   944
# 10 ORD   733

# %% [markdown]
# #### 수업내용

# %%
select(flights, year, month, day) %>% head()
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
select(flights, year:day) %>% head()
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
select(flights, -(year:day)) %>% head()
# Out:
#   dep_time sched_dep_time dep_delay arr_time sched_arr_time arr_delay carrier
# 1 517      515             2         830      819            11       UA
# 2 533      529             4         850      830            20       UA
# 3 542      540             2         923      850            33       AA
# 4 544      545            -1        1004     1022           -18       B6
# 5 554      600            -6         812      837           -25       DL
# 6 554      558            -4         740      728            12       UA
#   flight tailnum origin dest air_time distance hour minute time_hour
# 1 1545   N14228  EWR    IAH  227      1400     5    15     2013-01-01 05:00:00
# 2 1714   N24211  LGA    IAH  227      1416     5    29     2013-01-01 05:00:00
# 3 1141   N619AA  JFK    MIA  160      1089     5    40     2013-01-01 05:00:00
# 4  725   N804JB  JFK    BQN  183      1576     5    45     2013-01-01 05:00:00
# ...

# %% [markdown]
# ## Helper Functions
# - star_with("abc"): matches names that begin with "abc"
# - ends_with("xyz"): matches names that end with "xyz"
# - contains("ijk"): matches names that contain "ijk"
# - num_range("x", 1:3): matches x1, x2 and x3

# %%
select(flights, starts_with("arr")) %>% head()
# Out:
#   arr_time arr_delay
# 1  830      11
# 2  850      20
# 3  923      33
# 4 1004     -18
# 5  812     -25
# 6  740      12

# %%
select(flights, contains("arr")) %>% head()
# Out:
#   arr_time sched_arr_time arr_delay carrier
# 1  830      819            11       UA
# 2  850      830            20       UA
# 3  923      850            33       AA
# 4 1004     1022           -18       B6
# 5  812      837           -25       DL
# 6  740      728            12       UA

# %% [markdown]
# - Rename the variable with rename()

# %%
colnames(flights)[12]
# Out:
# [1] "tailnum"

# %%
rename(flights, tail_num=tailnum) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tail_num origin dest air_time distance hour minute
# 1  11       UA      1545   N14228   EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211   LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA   JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB   JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN   LGA    ATL  116       762     6     0
# ...

# %%
select(flights, time_hour, air_time, everything()) %>% head()
# Out:
#   time_hour           air_time year month day dep_time sched_dep_time dep_delay
# 1 2013-01-01 05:00:00 227      2013 1     1   517      515             2
# 2 2013-01-01 05:00:00 227      2013 1     1   533      529             4
# 3 2013-01-01 05:00:00 160      2013 1     1   542      540             2
# 4 2013-01-01 05:00:00 183      2013 1     1   544      545            -1
# 5 2013-01-01 06:00:00 116      2013 1     1   554      600            -6
# 6 2013-01-01 05:00:00 150      2013 1     1   554      558            -4
#   arr_time sched_arr_time arr_delay carrier flight tailnum origin dest distance
# 1  830      819            11       UA      1545   N14228  EWR    IAH  1400
# 2  850      830            20       UA      1714   N24211  LGA    IAH  1416
# 3  923      850            33       AA      1141   N619AA  JFK    MIA  1089
# 4 1004     1022           -18       B6       725   N804JB  JFK    BQN  1576
# ...

# %% [markdown]
# # Add new variables with mutate()

# %%
 flights %>% select(year:day, ends_with("delay"), distance, air_time) %>% head()
# Out:
#   year month day dep_delay arr_delay distance air_time
# 1 2013 1     1    2         11       1400     227
# 2 2013 1     1    4         20       1416     227
# 3 2013 1     1    2         33       1089     160
# 4 2013 1     1   -1        -18       1576     183
# 5 2013 1     1   -6        -25        762     116
# 6 2013 1     1   -4         12        719     150

# %%
flights %>%
    select(year:day, ends_with("delay"), distance, air_time) %>%
    mutate(gain = dep_delay - arr_delay,
            hours = air_time / 60,
            gain_per_hour = gain / hours) %>% head()
# Out:
#   year month day dep_delay arr_delay distance air_time gain hours
# 1 2013 1     1    2         11       1400     227       -9  3.783333
# 2 2013 1     1    4         20       1416     227      -16  3.783333
# 3 2013 1     1    2         33       1089     160      -31  2.666667
# 4 2013 1     1   -1        -18       1576     183       17  3.050000
# 5 2013 1     1   -6        -25        762     116       19  1.933333
# 6 2013 1     1   -4         12        719     150      -16  2.500000
#   gain_per_hour
# 1  -2.378855
# 2  -4.229075
# 3 -11.625000
# 4   5.573770
# 5   9.827586
# 6  -6.400000

# %%
flights_new = flights %>%
                select(year:day, ends_with("delay"), distance, air_time) %>%
                mutate(gain = dep_delay - arr_delay,
                        hours = air_time / 60,
                        gain_per_hour = gain / hours) %>% head()

# %% [markdown]
# # Grouped summaries with summarise()

# %%
flights[1:3, ]
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515            2         830      819
# 2 2013 1     1   533      529            4         850      830
# 3 2013 1     1   542      540            2         923      850
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 11        UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2 20        UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3 33        AA      1141   N619AA  JFK    MIA  160      1089     5    40
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00

# %%
flights %>% group_by(origin) %>%
summarise(delay=mean(dep_delay, na.rm = TRUE),
          delay_sd= sd(dep_delay, na.rm = TRUE),
          n= n())
# Out:
#   origin delay    delay_sd n
# 1 EWR    15.10795 41.32370 120835
# 2 JFK    12.11216 39.03507 111279
# 3 LGA    10.34688 39.99302 104662

# %%
flights %>% group_by(dest) %>%
summarise(delay=mean(dep_delay, na.rm = TRUE)) %>% head()
# Out:
#   dest delay
# 1 ABQ  13.740157
# 2 ACK   6.456604
# 3 ALB  23.620525
# 4 ANC  12.875000
# 5 ATL  12.509824
# 6 AUS  13.025641

# %%
flights %>% group_by(year, month, day) %>%
summarise(delay=mean(dep_delay, na.rm = TRUE)) %>% head()
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#   year month day delay
# 1 2013 1     1   11.548926
# 2 2013 1     2   13.858824
# 3 2013 1     3   10.987832
# 4 2013 1     4    8.951595
# 5 2013 1     5    5.732218
# 6 2013 1     6    7.148014

# %%
 flights %>% group_by(dest) %>%
  summarise(count=n(), dist= mean(distance, na.rm=TRUE), delay = mean(arr_delay, na.rm= TRUE)) %>%
  filter(count > 20, dest != "HNL") %>% head()
# Out:
#   dest count dist      delay
# 1 ABQ    254 1826.0000  4.381890
# 2 ACK    265  199.0000  4.852273
# 3 ALB    439  143.0000 14.397129
# 4 ATL  17215  757.1082 11.300113
# 5 AUS   2439 1514.2530  6.019909
# 6 AVL    275  583.5818  8.003831

# %% [markdown]
# It looks like delays increase with distance up to ~750 miles and then decrease. Maybe as flights get longer there's more ability to make up delays in the air?

# %%
 flights %>% group_by(dest) %>%
  summarise(count=n(), dist= mean(distance, na.rm=TRUE), delay = mean(arr_delay, na.rm= TRUE)) %>%
  filter(count > 20, dest != "HNL") %>% 
ggplot(mapping= aes(x=dist, y=delay)) +
  geom_point(aes(size=count), alpha=1/3) +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# # Data Visuallization - ggplot

# %% [markdown]
# #### HW1 추가코드

# %%
head(USArrests)
# Out:
#            Murder Assault UrbanPop Rape
# Alabama    13.2   236     58       21.2
# Alaska     10.0   263     48       44.5
# Arizona     8.1   294     80       31.0
# Arkansas    8.8   190     50       19.5
# California  9.0   276     91       40.6
# Colorado    7.9   204     78       38.7

# %%
ggplot(data = USArrests) +
    geom_point(mapping = aes(Murder, Assault), color="blue", alpha = 0.8, shape = 2) +
    geom_smooth(mapping= aes(Murder, Assault)) + 
    geom_line(mapping= aes(Murder, Assault))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# #### 수업내용

# %%
# ggplot(data= <DATA>) + <GEOM_FUNCTION>(mapping = aes(<MAPPING>))
# aes(x=, y=, color=, size=, alpha=, shape=)
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
# ggplot(data = mpg, mapping= aes (x=displ, y=hwy)) + geom_point()

ggplot(data = mpg) +
  geom_point(mapping= aes (x=displ, y=hwy))
# Out:
# plot without title

# %%
# 하나하나 mapping 넣어줘야함
ggplot(data = mpg) +
  geom_point(mapping= aes (x=displ, y=hwy)) +
  geom_smooth(mapping= aes (x=displ, y=hwy)) + 
  geom_line(mapping= aes (x=displ, y=hwy))

# size나 color, alpha 등을 넣어볼 수 있음
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# # Facet

# %%
ggplot(data=mpg) + 
    geom_point(mapping = aes (x=displ, y=hwy)) +
    facet_wrap(~ class, nrow=2)
# Out:
# plot without title

# %%
ggplot(data=mpg) + 
    geom_point(mapping = aes (x=displ, y=hwy)) +
    facet_grid(drv ~ cyl)
# Out:
# plot without title

# %% [markdown]
# # Theme

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + theme_bw() +
  theme(axis.line = element_line(size=8, colour = "black"),
        panel.grid.minor = element_blank(),
        text = element_text(size=25))
# Out:
# plot without title
